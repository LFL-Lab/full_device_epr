# %%
# %load_ext autoreload
# %autoreload 2
from qiskit_metal import draw, Dict, designs, MetalGUI
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent
import qiskit_metal as metal
from just_claw import TransmonClaw
# ?metal.qlibrary.core.QComponent.add_qgeometry

design = metal.designs.design_planar.DesignPlanar()
gui = metal.MetalGUI(design)
design.overwrite_enabled = True

# dir(QComponent)
cpw_width = '11.7um'

design._chips.main.size.size_x = '5mm'
design._chips.main.size.size_y = '5mm'
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.mixed_path import RouteMixed
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.couplers.cap_n_interdigital_tee import CapNInterdigitalTee
from qiskit_metal.qlibrary.couplers.line_tee import LineTee

from collections import OrderedDict

import numpy as np

xmon1_options = dict(
    connection_pads = dict(
        readout = dict(
            connector_location='90',
            connector_type='0',
            claw_length="1um",
            ground_spacing='4.1um',
            claw_gap='5.1um',
            claw_width='15um',
            claw_cpw_length=0
        ),
    ),
    cross_width='30um',
    cross_length="100um",
    cross_gap='30um',
    orientation='-90',
    pos_x='-1500um',
    pos_y='1200um',
    # aedt_hfss_inductance=inductance,
    # hfss_inductance=inductance, 
    # q3d_inductance=inductance,
    # aedt_q3d_inductance=inductance
)

# Create a new Transmon Cross object with name 'Q1'
q = TransmonClaw(design, 'Q', options=xmon1_options)

clt1_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '-90',
                pos_y = '1200um',
                down_length = '50um')

clt = CoupledLineTee(design, 'clt', clt1_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw1_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q',
                                                  pin = 'readout')),
                lead = Dict(end_straight = '70um',
                            # start_jogged_extension = jogsS),
                ),
                fillet = '49.9um',
                total_length = '3900um',#'3893.8166um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um',)
cpw = RouteMeander(design, 'cpw', options = cpw1_opts)

gui.rebuild()
gui.autoscale()
# gui.zoom_on_components(['clt5', 'Q5'])
# gui.screenshot()

# %%
# predicted_cross_length = [211.36686180080213, 239.67001841727927, 199.29546197022296, 272.80405439803087, 166.21118594572997]
# predicted_claw_length = [62.74561331858793, 238.54614619784087, 166.65135380618355, 49.04728878924247, 122.98283288276569]
# Lj_vals = [10.130278903289723, 8.837126261668763, 10.545628251119771, 7.934490145874526, 12.130125654474945]

vec1 = (12.101812915800638, 165.60709433301977, 142.67234304675804)
vec2 = (10.092518176996967, 210.20946233643153, 201.9365897494747)
Lj_vals = []
predicted_cross_length = []
predicted_claw_length = []

for Lj, xlen, clen in [vec1, vec2]:
    Lj_vals += [Lj]
    predicted_cross_length += [xlen]
    predicted_claw_length += [clen]

# %%
from qiskit_metal.analyses.quantization import EPRanalysis
import pyEPR as epr
from pyaedt import Hfss
from utils import *
from objects import *

# %% [markdown]
# # Eigenmode Sim (CLT + CPW + Claw)

# %%
eig_q12bus = EPRanalysis(design, "hfss")

# %%
def do_eigenmode(claw_length, Lj, index):                
    design.components['Q'].options['connection_pads']['readout']['claw_length'] = f'{claw_length}um'
    design.components['Q'].options['hfss_inductance'] = Lj
    design.components['Q'].options['aedt_hfss_inductance'] = Lj
    design.components['Q'].options['q3d_inductance'] = Lj
    design.components['Q'].options['aedt_q3d_inductance'] = Lj
    design.rebuild()

    eig_q12bus = EPRanalysis(design, "hfss")
    hfss = eig_q12bus.sim.renderer
    hfss.start()

    hfss.new_ansys_design(f"Cavity_Claw{index}", 'eigenmode')
    hfss.render_design([qubit_name, feedline_name, cavity_name])  # List of components to include in the simulation

    eig_q12bus.sim.setup.max_passes = 50
    eig_q12bus.sim.setup.max_delta_f = 0.1
    eig_q12bus.sim.setup.n_modes = 2

    sim_setup_var_dict = dict()

    key_Lj = 'Lj'
    key_Cj = 'Cj'
    sim_setup_var_dict[key_Lj] = str(design.components['Q'].options['hfss_inductance']) + ' H'
    sim_setup_var_dict[key_Cj] = str(design.components['Q'].options['hfss_capacitance']) + ' F'
    eig_q12bus.sim.setup.vars = sim_setup_var_dict

    gui.rebuild()
    gui.autoscale()

    # aedt = Hfss(projectname=hfss.pinfo.project_name, 
    #             designname=hfss.pinfo.design.name, 
    #             solution_type='eigenmode',
    #             new_desktop_session=False, 
    #             close_on_exit=False)
    # materials = aedt.materials
    # silicon = materials.checkifmaterialexists('silicon')
    # silicon.permittivity = 11.45
    # silicon.dielectric_loss_tangent = 1E-7
    
    qubit_name = "Q"
    feedline_name = "cpw"
    cavity_name = "clt"
    mesh_lengths = {'mesh1': {"objects": [f"cross_{'qubit_name'}",f"readout_connector_arm_{qubit_name}",f"prime_cpw_{feedline_name}", f"second_cpw_{feedline_name}", f"trace_{cavity_name}", f"readout_connector_arm_{feedline_name}"], "MaxLength": '4um'},
                    'mesh2': {'objects': [f"JJ_rect_Lj_{qubit_name}_rect_jj"], "MaxLength": '2um'}
                    }
    add_ground_strip_and_mesh(hfss.pinfo.design.modeler, clt, mesh_lengths)


    eig_q12bus.sim.run(name='full_device_v1.0',
                    components=['Q', 'cpw', 'clt'],
                    open_terminations = [('clt', 'prime_start'), ('clt', 'prime_end')],
                    port_list = [('clt', 'prime_start', '50'), ('clt', 'prime_end', '50')]
                    )
    
    f = eig_q12bus.get_frequencies()

    freq = f.values[0][0] * 1e9 # in linear Hz
    Q = f.values[0][1]
    kappa_emode = {round(freq/Q/1e6, 3)} # in linear MHz

    return f,Q,kappa_emode

# %%
# %matplotlib inline
eig_q12bus = EPRanalysis(design, "hfss")
hfss = eig_q12bus.sim.renderer

# i = 4
# setups, hfsss = [], []

# do_eigenmode(predicted_claw_length[1], Lj_vals[1])



for i, (cross_length, claw_length, Lj) in enumerate(zip(predicted_cross_length, predicted_claw_length, Lj_vals)):
# claw_length = predicted_claw_length[0]
# Lj = Lj_vals[0]
# i = 0
    # freq, Q, kappa_emode = do_eigenmode(claw_length, Lj, i)
    # data_df = {
    #     "frequency": freq,
    #     "Q": Q,
    #     "kappa_emode": kappa_emode
    # }
        
    # filename = f"cavity_claw_{i}"
    # save_simulation_data_to_json(data_df, filename)
    xmon1_options["connection_pads"]["readout"]["claw_length"] = f"{claw_length}um"
    xmon1_options["aedt_hfss_inductance"]=Lj,
    xmon1_options["hfss_inductance"]=Lj, 
    xmon1_options["q3d_inductance"]=Lj,
    xmon1_options["aedt_q3d_inductance"]=Lj
    
    v2_opts = dict(
        claw_opts = xmon1_options,
        cplr_opts = clt1_opts,
        cpw_opts = cpw1_opts
    )
    CLT_epr_sweep(design = design, sweep_opts=v2_opts, filename = f"cavity_claw_{i}_v2")
# Out:
# INFO 06:25PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 06:25PM [load_ansys_project]: 	Opened Ansys App
# INFO 06:25PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 06:25PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/lfl/Documents/Ansoft/
# 	Project:   Project41
# Starting the Simulation
# INFO 06:25PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep_hfss [Solution type: Eigenmode]
# INFO 06:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 06:25PM [connect]: 	Connected to project "Project41" and design "CavitySweep_hfss" 😀
#
# INFO 06:25PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep7 [Solution type: Eigenmode]
# WARNING 06:25PM [connect_setup]: 	No design setup detected.
# WARNING 06:25PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 06:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 06:25PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep_hfss [Solution type: Eigenmode]
# creaing porst
# Sim rendered into HFSS!
# pyaedt INFO: using existing logger.
# INFO:Global:using existing logger.
# pyaedt INFO: Launching PyAEDT outside AEDT with CPython and PythonNET.
# INFO:Global:Launching PyAEDT outside AEDT with CPython and PythonNET.
# pyaedt INFO: AEDT installation Path D:\Program Files\AnsysEM\AnsysEM21.1\Win64.
# INFO:Global:AEDT installation Path D:\Program Files\AnsysEM\AnsysEM21.1\Win64.
# pyaedt INFO: Launching AEDT with module PythonNET.
# INFO:Global:Launching AEDT with module PythonNET.
# pyaedt WARNING: PyAEDT is not supported in AEDT versions earlier than 2021 R2. Trying to launch PyAEDT with PyWin32.
# WARNING:Global:PyAEDT is not supported in AEDT versions earlier than 2021 R2. Trying to launch PyAEDT with PyWin32.
# pyaedt INFO: pyaedt v0.6.46
# INFO:Global:pyaedt v0.6.46
# pyaedt INFO: Python version 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 17:59:51) [MSC v.1935 64 bit (AMD64)]
# INFO:Global:Python version 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 17:59:51) [MSC v.1935 64 bit (AMD64)]
# pyaedt INFO: Project Project41 set to active.
# INFO:Global:Project Project41 set to active.
# pyaedt INFO: Aedt Objects initialized
# INFO:Global:Aedt Objects initialized
# pyaedt INFO: Variable Manager initialized
# INFO:Global:Variable Manager initialized
# pyaedt INFO: Design Loaded
# INFO:Global:Design Loaded
# pyaedt INFO: Successfully loaded project materials !
# INFO:Global:Successfully loaded project materials !
# pyaedt INFO: Materials Loaded
# INFO:Global:Materials Loaded
# pyaedt INFO: Project files removed from handlers.
# INFO:Global:Project files removed from handlers.
# INFO 06:26PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 06:26PM [analyze]: Analyzing setup Setup
# 09:21PM 34s INFO [get_f_convergence]: Saved convergences to d:\andre\full device epr\hfss_eig_f_convergence.csv
# INFO 09:21PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# Design "CavitySweep_hfss" info:
# 	# eigenmodes    1
# 	# variations    1
# Design "CavitySweep_hfss" info:
# 	# eigenmodes    1
# 	# variations    1
# INFO 09:21PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 09:21PM [load_ansys_project]: 	Opened Ansys App
# INFO 09:21PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 09:21PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/lfl/Documents/Ansoft/
# 	Project:   Project41
# freq = 6.587 GHz
# Q = 45720.8
# kappa = 0.144 MHz
# Starting the Simulation
# INFO 09:22PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep_hfss [Solution type: Eigenmode]
# INFO 09:22PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:22PM [connect]: 	Connected to project "Project41" and design "CavitySweep_hfss" 😀
#
# INFO 09:22PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep8 [Solution type: Eigenmode]
# WARNING 09:22PM [connect_setup]: 	No design setup detected.
# WARNING 09:22PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 09:22PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:22PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep_hfss [Solution type: Eigenmode]
# creaing porst
# Sim rendered into HFSS!
# pyaedt INFO: using existing logger.
# INFO:Global:using existing logger.
# pyaedt INFO: Launching PyAEDT outside AEDT with CPython and PythonNET.
# INFO:Global:Launching PyAEDT outside AEDT with CPython and PythonNET.
# pyaedt INFO: AEDT installation Path D:\Program Files\AnsysEM\AnsysEM21.1\Win64.
# INFO:Global:AEDT installation Path D:\Program Files\AnsysEM\AnsysEM21.1\Win64.
# pyaedt INFO: Launching AEDT with module PythonNET.
# INFO:Global:Launching AEDT with module PythonNET.
# pyaedt WARNING: PyAEDT is not supported in AEDT versions earlier than 2021 R2. Trying to launch PyAEDT with PyWin32.
# WARNING:Global:PyAEDT is not supported in AEDT versions earlier than 2021 R2. Trying to launch PyAEDT with PyWin32.
# pyaedt INFO: pyaedt v0.6.46
# INFO:Global:pyaedt v0.6.46
# pyaedt INFO: Python version 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 17:59:51) [MSC v.1935 64 bit (AMD64)]
# INFO:Global:Python version 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 17:59:51) [MSC v.1935 64 bit (AMD64)]
# pyaedt INFO: Project Project41 set to active.
# INFO:Global:Project Project41 set to active.
# pyaedt INFO: Aedt Objects initialized
# INFO:Global:Aedt Objects initialized
# pyaedt INFO: Variable Manager initialized
# INFO:Global:Variable Manager initialized
# pyaedt INFO: Design Loaded
# INFO:Global:Design Loaded
# pyaedt INFO: Successfully loaded project materials !
# INFO:Global:Successfully loaded project materials !
# pyaedt INFO: Materials Loaded
# INFO:Global:Materials Loaded
# pyaedt INFO: Project files removed from handlers.
# INFO:Global:Project files removed from handlers.
# INFO 09:22PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:22PM [analyze]: Analyzing setup Setup
# 12:06AM 47s INFO [get_f_convergence]: Saved convergences to d:\andre\full device epr\hfss_eig_f_convergence.csv
# INFO 12:06AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# Design "CavitySweep_hfss" info:
# 	# eigenmodes    1
# 	# variations    1
# Design "CavitySweep_hfss" info:
# 	# eigenmodes    1
# 	# variations    1
# freq = 6.412 GHz
# Q = 48631.3
# kappa = 0.132 MHz

# %% [markdown]
# # LOM Analysis

# %%
xmon = TransmonCross(design = design, options = xmon1_options, name = "xmon")

# %%
from qiskit_metal.analyses.quantization import LOManalysis
c1 = LOManalysis(design, "q3d")

# %%
from qiskit_metal.analyses.quantization import LOManalysis
c1 = LOManalysis(design, "q3d")

# %%
c1.sim.setup.reuse_selected_design = False
c1.sim.setup.reuse_setup = False

# example: update single setting
c1.sim.setup.max_passes = 30
c1.sim.setup.min_converged_passes = 1
c1.sim.setup.percent_error = 0.1
c1.sim.setup.name = 'sweep_setup'

# %%
def do_LOM_qubitonly(cross_length, claw_length, Lj, i):
    qname = 'xmon'
    cname = 'readout'

    design.components[qname].options['connection_pads']['readout']['claw_length'] = f'{claw_length}um'
    design.components[qname].options['cross_length'] = f'{cross_length}um'
    design.components[qname].options['hfss_inductance'] = Lj
    design.components[qname].options['aedt_hfss_inductance'] = Lj
    design.components[qname].options['q3d_inductance'] = Lj
    design.components[qname].options['aedt_q3d_inductance'] = Lj
    design.rebuild()

    selection = [qname]
    open_pins = [(qname, cname)]


    c1.sim.run(name = 'LOMv2.0', components=selection,
               open_terminations=open_pins)
    cap_df = c1.sim.capacitance_matrix

    print(f'For Qubit_{i}, the cap matrix is...')
    print(cap_df)

    data = {
        "design_options": design.components[qname].options,
        "data": {
            "cross_to_ground": cap_df.loc[f'cross_{qname}']['ground_main_plane'],
            "claw_to_ground": cap_df.loc[f'{cname}_connector_arm_{qname}']['ground_main_plane'],
            "cross_to_claw": cap_df.loc[f'cross_{qname}'][f'{cname}_connector_arm_{qname}'],
            "cross_to_cross": cap_df.loc[f'cross_{qname}'][f'cross_{qname}'],
            "claw_to_claw": cap_df.loc[f'{cname}_connector_arm_{qname}'][f'{cname}_connector_arm_{qname}'],
            "ground_to_ground": cap_df.loc['ground_main_plane']['ground_main_plane']
        },
        "sim_info": {
            "setup": c1.sim.setup,
            "renderer_options": c1.sim.renderer.options
        }
    }
    save_simulation_data_to_json(data, filename = f"qubitonly_{i}_v2.1")

# %%
all_cap_matricies = []

for i, (cross_length, claw_length, Lj) in enumerate(zip(predicted_cross_length, predicted_claw_length, Lj_vals)):
    # if i != 1:
    #     continue
    do_LOM_qubitonly(cross_length, claw_length, Lj, i)
# Out:
# INFO 01:11PM [connect_design]: 	Opened active design
# 	Design:    LOMv2.0_q3d15 [Solution type: Q3D]
# WARNING 01:11PM [connect_setup]: 	No design setup detected.
# WARNING 01:11PM [connect_setup]: 	Creating Q3D default setup.
# INFO 01:11PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 01:11PM [get_setup]: 	Opened setup `sweep_setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 01:11PM [analyze]: Analyzing setup sweep_setup
# <COMObject GetModule>
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpguwxuq86.txt, C, , sweep_setup:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpqf8ioefp.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp78vqejh_.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7qap5295.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpv0kmtn9s.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp9rq52cpt.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpc7qs5blt.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpx_h74nsv.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmptm6shc5j.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_u7_ey2r.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp4e7hszcb.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmphjyjgetk.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpuilt8ya5.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_xxfs7d1.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpwyndlvzj.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 01:13PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpo19c_zm8.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# For Qubit_0, the cap matrix is...
#                             cross_xmon  ground_main_plane  \
# cross_xmon                    85.29643          -77.99951
# ground_main_plane            -77.99951          199.00772
# readout_connector_arm_xmon    -5.39135          -73.91245
#
#                             readout_connector_arm_xmon
# cross_xmon                                    -5.39135
# ground_main_plane                            -73.91245
# readout_connector_arm_xmon                    79.85653
# INFO 01:13PM [connect_design]: 	Opened active design
# 	Design:    LOMv2.0_q3d16 [Solution type: Q3D]
# WARNING 01:13PM [connect_setup]: 	No design setup detected.
# WARNING 01:13PM [connect_setup]: 	Creating Q3D default setup.
# INFO 01:13PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 01:13PM [get_setup]: 	Opened setup `sweep_setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# <COMObject GetModule>
# INFO 01:13PM [analyze]: Analyzing setup sweep_setup
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpi7eqyx9m.txt, C, , sweep_setup:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp4y86ez3s.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_zuilwaq.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpbdckuh3t.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmprzf8pn5l.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpxbfr1ezm.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp0qr_c6sm.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpidqzdg8u.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpndfwbw6_.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpgy0b3kon.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjws4qll0.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpirqwgkf0.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmprgz55uxo.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpuqifax1a.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpiph7txxk.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpusccb83_.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp5j0s5cwu.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpsw4ywsve.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# INFO 01:16PM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp4gpo1idj.txt, C, , sweep_setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 18, False
# For Qubit_1, the cap matrix is...
#                             cross_xmon  readout_connector_arm_xmon
# cross_xmon                   109.53723                    -8.66487
# readout_connector_arm_xmon    -8.66487                   101.67120
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ground_main_plane'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\andre\full device epr\full_device_sim copy.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> all_cap_matricies = []
#       <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> for i, (cross_length, claw_length, Lj) in enumerate(zip(predicted_cross_length, predicted_claw_length, Lj_vals)):
#       <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     # if i != 1:
#       <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     #     continue
# ----> <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     do_LOM_qubitonly(cross_length, claw_length, Lj, i)
#
# d:\andre\full device epr\full_device_sim copy.ipynb Cell 14 line 2
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> print(f'For Qubit_{i}, the cap matrix is...')
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=21'>22</a> print(cap_df)
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=23'>24</a> data = {
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=24'>25</a>     "design_options": design.components[qname].options,
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=25'>26</a>     "data": {
# ---> <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=26'>27</a>         "cross_to_ground": cap_df.loc[f'cross_{qname}']['ground_main_plane'],
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=27'>28</a>         "claw_to_ground": cap_df.loc[f'{cname}_connector_arm_{qname}']['ground_main_plane'],
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=28'>29</a>         "cross_to_claw": cap_df.loc[f'cross_{qname}'][f'{cname}_connector_arm_{qname}'],
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=29'>30</a>         "cross_to_cross": cap_df.loc[f'cross_{qname}'][f'cross_{qname}'],
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=30'>31</a>         "claw_to_claw": cap_df.loc[f'{cname}_connector_arm_{qname}'][f'{cname}_connector_arm_{qname}'],
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=31'>32</a>         "ground_to_ground": cap_df.loc['ground_main_plane']['ground_main_plane']
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=32'>33</a>     },
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=33'>34</a>     "sim_info": {
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=34'>35</a>         "setup": c1.sim.setup,
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=35'>36</a>         "renderer_options": c1.sim.renderer.options
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=36'>37</a>     }
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=37'>38</a> }
#      <a href='vscode-notebook-cell:/d%3A/andre/full%20device%20epr/full_device_sim%20copy.ipynb#X16sZmlsZQ%3D%3D?line=38'>39</a> save_simulation_data_to_json(data, filename = f"qubitonly_{i}_v2.1")
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'ground_main_plane'
